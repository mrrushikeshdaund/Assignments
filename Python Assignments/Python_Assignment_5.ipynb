# %% [markdown]
# <h1 align="center">Assignment No 5</h1>

# %% [markdown]
# Q1. What does an empty dictionary's code look like?

# %%
d = {}
print(d)
# Out:
# {}

# %% [markdown]
# to create an empty dictionary
# - first create a variable name which will be the name of dictionary
# - after that assign a variable to an empty curly braces like this ```{}```

# %% [markdown]
# Q2. What is the value of a dictionary value with the key 'foo' and the value 42?

# %%
d = {'foo':42}
print(d)
# Out:
# {'foo': 42}

# %% [markdown]
# if the value is present in the dictionary they show like above example otherwise it is not found in the dictionary they return Keyerror that means key is not in that dictionary

# %% [markdown]
# Q3. What is the most significant distinction between a dictionary and a list?

# %% [markdown]
# List | Dictionary
# - | -
# a list refers to a collection of various index value pairs | a dictionary refers to a hashed structure of various pairs of keys and values.
# we can create a list by using ```[ ]```and add elements in it. | we can create a dictionary by placing all the available elements into a ```{ }```
# in a List index is integer from 0 to N | in a Dictionary index is noting but a key any data type it will be string char anything.
# for example ```ls = [10,45,6,'hello']``` | for example ```ds = {'number':1,'new':89}```

# %% [markdown]
# Q5. If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and 'cat' in spam.keys()?

# %% [markdown]
# actually there is no difference in that the in operator checks if ```'cat' in spam ``` key is present in dictionary then it will return True otherwise False ```spam.keys()``` it will return all key in that spam

# %% [markdown]
# Q6. If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and 'cat' in spam.values()?

# %%
spam = {}
'cat' in spam
# Out:
# False

# %%
spam = {}
spam.values()
# Out:
# dict_values([])

# %% [markdown]
# - In case 'cat' in spam it will return false if cat is present in that then it will return True
# - In case of spam.values() it will return all values in the spam dictionary

# %% [markdown]
# Q7. What is a shortcut for the following code?
# ```python
# if 'color' not in spam:
# spam['color'] = 'black' ```

# %%
result = spam.setdefault('color','black')
result
# Out:
# 'black'

# %% [markdown]
# Q8. How do you "pretty print" dictionary values using which module and function?

# %%
import pprint
pprint.pprint(result)
# Out:
# 'black'
