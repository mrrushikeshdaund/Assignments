# %% [markdown]
# <h1 align = "center">Assignment No 4</h1>

# %% [markdown]
# Q1. What exactly is []?

# %% [markdown]
# ```[]``` The Empty List Value it means this list contain on elements.or we can call it as Null List

# %% [markdown]
# Q2. In a list of values stored in a variable called spam, how would you assign the value 'hello' as the third value?<br> (Assume [2, 4, 6, 8, 10] are in spam.)
# <br>
# Let's pretend the spam includes the list ['a', 'b', 'c', 'd'] for the next three queries.

# %% [markdown]
# this is a list ``` spam = [2, 4, 6, 8, 10] ``` now i want to store 'Hello' at the third postion
# ``` spam[2] = 'hello' ```

# %%
spam = [2, 4, 6, 8, 10]

# %%
spam[2] = 'hello'

# %%
spam
# Out:
# [2, 4, 'hello', 8, 10]

# %% [markdown]
# Q3. What is the value of spam[int(int('3' * 2) / 11)]?

# %%
print(f"The Value OF Above Exp is {spam[int(int('3' * 2) / 11)]}")
# Out:
# The Value OF Above Exp is 8

# %% [markdown]
# Q4. What is the value of spam[-1]?

# %%
print(f"The Value of Spam[-1] is {spam[-1]}")
# Out:
# The Value of Spam[-1] is 10

# %% [markdown]
# Q5. What is the value of spam[:2]?<br>
# Let's pretend bacon has the list [3.14, 'cat,' 11, 'cat,' True] for the next three questions

# %%
print(f"The Value of Spam[:2] is {spam[:2]}")
# Out:
# The Value of Spam[:2] is [2, 4]

# %%
bacon = [3.14, 'cat', 11, 'cat', True]

# %% [markdown]
# Q6. What is the value of bacon.index('cat')?

# %%
print(f"The Value Of Bacon.index('cat') is {bacon.index('cat')}")
# Out:
# The Value Of Bacon.index('cat') is 1

# %% [markdown]
# Q7. How does bacon.append(99) change the look of the list value in bacon?

# %%
bacon.append(99)
print(bacon)
# Out:
# [3.14, 'cat', 11, 'cat', True, 99]

# %% [markdown]
# Q8. How does bacon.remove('cat') change the look of the list in bacon?

# %%
bacon.remove('cat')
bacon
# Out:
# [3.14, 11, 'cat', True, 99]

# %% [markdown]
# Q9. What are the list concatenation and list replication operators?

# %% [markdown]
# - list concatenation
#   - list concatention is used to join or adding two list in one list
#   - here spam and bacon both are list now we can apply concatenation operation on top it and it will merge two list.

# %%
print(spam+bacon)
# Out:
# [2, 4, 'hello', 8, 10, 3.14, 11, 'cat', True, 99]

# %% [markdown]
# - list replication
#   - list replication is used to replicate elements in the list
#   - we can multiply by list for replication purpose.

# %%
print(spam*4)
# Out:
# [2, 4, 'hello', 8, 10, 2, 4, 'hello', 8, 10, 2, 4, 'hello', 8, 10, 2, 4, 'hello', 8, 10]

# %% [markdown]
# Q10. What is difference between the list methods append() and insert()?

# %% [markdown]
# Append() | Insert ()
# - | -
#  In append function we can passed element as <br> an argument is appended to the end of the list | In Insert function we can passed element and index <br>of particular postion to insert an element in the list.
# it appends without any change as a single <br>element to the end of the list | it insert desired index of the list
# list.append(element) | list.insert(element,index)
# In append only one paramenter is mandatary | In insert there are two parameter are mandatary

# %% [markdown]
# Q11. What are the two methods for removing items from a list?

# %% [markdown]
# - remove method  ```list1.remove('cat')```
# - pop method    ```list1.pop()```

# %%
# for Example
list1 = [10,20,'cat']

list1.remove('cat')
print(f"after apply remove function : {list1}")

list1.pop()
print(f"after apply pop function : {list1}")
# Out:
# after apply remove function : [10, 20]
# after apply pop function : [10]

# %% [markdown]
# Q12. Describe how list values and string values are identical.

# %% [markdown]
# - List values
#   - list values are the sequential collection of the python data type value where each value is identified by an index.
#   - list are identical by there buckets ```[]```
#   - ```ls = [10,20,30,90,67]```
#
# - String values
#   - string is collection of character that value where each value is identified by an index.
#   - string is complete sentance or a words
#   - it is denoted by ```' '```
#   - ```s1 = "Hello"```

# %% [markdown]
# Q13. What's the difference between tuples and lists?

# %% [markdown]
# Tuples | Lists
# - | -
# we can't change value directly because Tuples are inmutable | we can change value directly because list are mutable
# tuples is denoted by round buckets ```( )``` | list is denoted by square buckets ```[ ]```
# we can't create empty tuple at least two or more elements<br> are allowed. | we can create empty list
# for example <br>```t1 = (2345,678)```  | for example <br>```ls = [10,3,6,'hello']```

# %% [markdown]
# Q14. How do you type a tuple value that only contains the integer 42?

# %%
tup1 = (42,)
tup1
# Out:
# (42,)

# %% [markdown]
# Q15. How do you get a list value's tuple form? How do you get a tuple value's list form?

# %% [markdown]
# - list value's tuple form

# %%
ls = [10,20,30,40,50]
tup1 = tuple(ls)
print(type(tup1))
print(tup1)
# Out:
# <class 'tuple'>
# (10, 20, 30, 40, 50)

# %% [markdown]
# - tuple value's list form

# %%
ls1 = list(tup1)
print(type(ls1))
print(ls1)
# Out:
# <class 'list'>
# [10, 20, 30, 40, 50]

# %% [markdown]
# Q16. Variables that "contain" list values are not necessarily lists themselves. Instead, what do they contain?

# %% [markdown]
# - Variables will contain references to the list values but in case of string and integer values variable contain the string and integer value

# %%
ls1 = [10,"hello",45.0,89]
print(f"list type {type(ls1)} list address : {id(ls1)}")
print(f"but list values type is different : {type(ls1[1])} and address {id(ls1[1])}")
print(f"but list values type is different : {type(ls1[0])} and address {id(ls1[0])}")
print(f"but list values type is different : {type(ls1[2])} and address {id(ls1[0])}")
# Out:
# list type <class 'list'> list address : 139896768201504
# but list values type is different : <class 'str'> and address 139896980278192
# but list values type is different : <class 'int'> and address 11122880
# but list values type is different : <class 'float'> and address 11122880

# %% [markdown]
# Q17. How do you distinguish between copy.copy() and copy.deepcopy()?

# %% [markdown]
# copy.copy() | copy.deepcopy()
# - | -
# create reference to the original object. | creates new object and does real copying of original object to new one

# %%
import copy
copy.copy(ls1)
# Out:
# [10, 'hello', 45.0, 89]

# %%
copy.deepcopy(ls1)
# Out:
# [10, 'hello', 45.0, 89]
