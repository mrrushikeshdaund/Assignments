# %% [markdown]
# <h3 align='center'>Assignment No 3</h3>

# %% [markdown]
# Q1. Why are functions advantageous to have in your programs?

# %% [markdown]
# Answer --> There Are Many Advantageous To Written Function
#
#
# 1. Function is a piece of code or we can call it as a number of steps to do a spacific tasks it is used for Doing Things.
# 2. We can avoid rewriting same logic again and again in a program
# 3. we can call functions any number of times in program from any place in a program.
# 4. we can track a large program easily when it divided in multiple functions.

# %% [markdown]
# Q2.When does the code in a function run: when it&#39;s specified or when it&#39;s called?

# %% [markdown]
# Answer --> when function is called the program leaves the current section of code and begins to execute the function code this as a flow of Function excuation and we can excute it by using there name i mean function name.

# %% [markdown]
# Q3. What statement creates a function?

# %% [markdown]
# function having define section there is syntax<br> def Function_Name(par1,par2,parn):
#
#
# > body of function
#
#
# > retrun type
#
#
#
#
# - let's it take example

# %%
def add(a,b):
  c = a + b
  return c

print(add(10,20))
# Out:
# 30

# %% [markdown]
# Q4. What is the difference between a function and a function call?

# %% [markdown]
# <table width="100%">
# <tr>
# <th>Function</th>
# <th>Function Call</th>
# </tr>
# <tr>
# <td>A function is block of code that do a particular operation and return a result.</td>
# <td>A function call is the code used to pass control to a function.
# </td>
# </tr>
#
# <tr>
# <td>function usually accepts inputs as parameters and returns a result.</td>
# <td>At the time of function call paramenter is in function then pass it otherwise pass blank .
# </td>
# </tr>
#
# <tr>
# <td>for Example <br>
# Function add(a,b)<br>
# return a+b </td>
# <td> for example<br>b = add(5,6).
# </td>
# </tr>
#
# </table>

# %% [markdown]
# Q5. How many global scopes are there in a Python program? How many local scopes?

# %% [markdown]
# In Python the scope of a name defines the area of the program. we can access the variables, function and objects
# There are two types of scope
# 1. global scope : The names that you define in this scope are available to all your code or we can call it as a variable that exits in the global scope.
#
# 2. Local scope : The names that you define in this scope are only available or visible to the code within the scope or the variable that exits in the local scope.

# %% [markdown]
# Q6. What happens to variables in a local scope when the function call returns?

# %% [markdown]
# In Local Scope variable we can access only within a function block or we can call it as in that indentation only
# 1. A local variable retains its value until the next time function is called
# 2. A local variable becomes underfined after the function call completes
# 3. The Local variable can be used outside the function any time after the function call completes

# %% [markdown]
# Q7. What is the concept of a return value? Is it possible to have a return value in an expression?

# %% [markdown]
# A function at return some sort of results in the form of values this values are called as return value. suppose for example<br> def add(a,b):<br> return a+b
#
# here in this function it return a+b values c = add(10,20)
# in C it return 30 as a results or output of this function
#
# it is possible as above example return expression a+b then calculate both the values and return final result as output of that function

# %% [markdown]
# Q8. If a function does not have a return statement, what is the return value of a call to that function?

# %% [markdown]
# A function that return nothing and there is no statement in that function block at that time it will return none <br> for example

# %%
def function_1(a,b):
  print(f"addition = {a+b}")

c = function_1(10,20)
print(c)
# print(a,b) If We Can't access it out of the block
# Out:
# addition = 30
# None

# %% [markdown]
# in an above example the a and b are the local variable we can't access out of the block.

# %% [markdown]
# Q9. How do you make a function variable refer to the global variable?

# %%
def add(global_va,x):
  global global_variable 
  global_variable = x
  print(f"Function Block  {global_variable} ")

add(22,3089)
print("Ouside the Function Block ",global_variable)
# Out:
# Function Block  3089
# Ouside the Function Block  3089

# %% [markdown]
# In this Example global_variable is a variable that can be access out of the function block

# %% [markdown]
# Q10. What is the data type of None?

# %%
type(None)
# Out:
# NoneType

# %% [markdown]
# The Data Type Of None is None Type

# %% [markdown]
# Q11. What does the sentence import are all your pets name deric do?

# %% [markdown]
# the import statement imports a module named areallyourpetsnamederic<br>
# we can import as many module imports in our code module by using import statement

# %% [markdown]
# Q12. If you had a bacon() feature in a spam module, what would you call it after importing spam?

# %% [markdown]
# we can call that function by using **spam.bacon()**

# %% [markdown]
# Q13. What can you do to save a programme from crashing if it encounters an error?

# %% [markdown]
# at the time of writing program we know the error in that particular line in that case we can place that error line in try block. then it show abnormal execution.

# %% [markdown]
# Q14. What is the purpose of the try clause? What is the purpose of the except clause?

# %% [markdown]
# In Program there are some runtime error or we can call it as exception. at that time we need to execute or terminate program abnormally then in that case we use Exception Handling in Python by using try and Except block.
