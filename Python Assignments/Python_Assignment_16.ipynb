# %% [markdown]
# <h1 align='center'>Assignment No 16</h1>

# %% [markdown]
# Q1. Create a list called years_list, starting with the year of your birth, and each year thereafter until
# the year of your fifth birthday. For example, if you were born in 1980. the list would be years_list =
# [1980, 1981, 1982, 1983, 1984, 1985].

# %%
def birthday_five_years(year_input):
  ls = []
  for i in range(6):
    ls.append(year_input+i)
  return ls

input_year = int(input("Enter Your Birthday year : "))
print(birthday_five_years(input_year))
# Out:
# Enter Your Birthday year : 1980
# [1980, 1981, 1982, 1983, 1984, 1985]

# %% [markdown]
# Q2. In which year in years_list was your third birthday? Remember, you were 0 years of age for your
# first year.

# %%
third_birthday = birthday_five_years(input_year)
print(third_birthday[2])
# Out:
# 1982

# %% [markdown]
# Q3.In the years list, which year were you the oldest?

# %%
print(third_birthday[-1])
# Out:
# 1985

# %% [markdown]
# Q4.Make a list called things with these three strings as elements: &quot;mozzarella&quot;, &quot;cinderella&quot;,
# &quot;salmonella&quot;.

# %%
things = ["mozzarella", "cinderella", "salmonella"]

# %% [markdown]
# Q5. Capitalize the element in things that refers to a person and then print the list. Did it change the
# element in the list?

# %%
output = map(lambda x:x.upper(),things)
print([i for i in output])
# Out:
# ['MOZZARELLA', 'CINDERELLA', 'SALMONELLA']

# %% [markdown]
# - its not change things list but we can assign it with another

# %% [markdown]
# Q6. Make a surprise list with the elements &quot;Groucho,&quot; &quot;Chico,&quot; and &quot;Harpo.&quot;

# %%
surprise_list = ["Groucho," "Chico,", "Harpo"]

# %% [markdown]
# Q7. Lowercase the last element of the surprise list, reverse it, and then capitalize it.

# %%
output = map(lambda d:d.swapcase(),surprise_list)
print([ i for i in output])
# Out:
# ['gROUCHO,cHICO,', 'hARPO']

# %% [markdown]
# Q8. Make an English-to-French dictionary called e2f and print it. Here are your starter words: dog is
# chien, cat is chat, and walrus is morse.

# %%
e2f = {'dog':'chien','cat':'chat','walrus':'morse'}

# %% [markdown]
# Q9. Write the French word for walrus in your three-word dictionary e2f.

# %%
e2f['walrus']
# Out:
# 'morse'

# %% [markdown]
# Q10. Make a French-to-English dictionary called f2e from e2f. Use the items method.

# %%
f2e = dict((key,value) for value,key in e2f.items())
f2e
# Out:
# {'chien': 'dog', 'chat': 'cat', 'morse': 'walrus'}

# %% [markdown]
# Q11. Print the English version of the French word chien using f2e.

# %%
f2e['chien']
# Out:
# 'dog'

# %%
f2e.values()
# Out:
# dict_values(['dog', 'cat', 'walrus'])

# %% [markdown]
# Q12. Make and print a set of English words from the keys in e2f.

# %%
f2e.keys()
# Out:
# dict_keys(['chien', 'chat', 'morse'])

# %% [markdown]
# Q13. Make a multilevel dictionary called life. Use these strings for the topmost keys: &#39;animals&#39;, &#39;plants&#39;,
# and &#39;other&#39;. Make the &#39;animals&#39; key refer to another dictionary with the keys &#39;cats&#39;, &#39;octopi&#39;, and
# &#39;emus&#39;. Make the &#39;cats&#39; key refer to a list of strings with the values &#39;Henri&#39;, &#39;Grumpy&#39;, and &#39;Lucy&#39;.
# Make all the other keys refer to empty dictionaries.

# %%
life ={'animals':{'cat':['Henri', 'Grumpy', 'Lucy'], 'octopi':'', 'emus':''},
       'plants' :'',
       'other' :'' }
life
# Out:
# {'animals': {'cat': ['Henri', 'Grumpy', 'Lucy'], 'octopi': '', 'emus': ''},
#  'plants': '',
#  'other': ''}

# %% [markdown]
# Q14. Print the top-level keys of life.

# %%
life.keys()
# Out:
# dict_keys(['animals', 'plants', 'other'])

# %% [markdown]
# Q15. Print the keys for life[&#39;animals&#39;].

# %%
life['animals'].keys()
# Out:
# dict_keys(['cat', 'octopi', 'emus'])

# %% [markdown]
# Q16. Print the values for life[&#39;animals&#39;][&#39;cats&#39;]

# %%
life['animals']['cat']
# Out:
# ['Henri', 'Grumpy', 'Lucy']
