# %% [markdown]
# <h1 align='center'>Assignment No 12</h1>

# %% [markdown]
# Q1 In what modes should the PdfFileReader() and PdfFileWriter() File objects will be opened?

# %% [markdown]
# - PdfFileReader() file objects should be opened in rb -> read binary mode,
# -  PdfFileWriter() file objects should be opened in wb -> write binary mode.

# %% [markdown]
# Q2 From a PdfFileReader object, how do you get a Page object for page 5?

# %% [markdown]
# - To extract text from a page, you need to get a Page object, which represents a single page of a PDF, from a PdfFileReader object.
# - You can get a Page object by calling the getPage() method on a PdfFileReader object and passing it the page number of the page
# - `pdfReader.getPage(5)`

# %% [markdown]
# Q3 What PdfFileReader variable stores the number of pages in the PDF document?

# %% [markdown]
# - The total number of pages in the document is stored in the `numPages attribute` of a PdfFileReader object

# %% [markdown]
# Q4 If a PdfFileReader object’s PDF is encrypted with the password swordfish, what must you do
# before you can obtain Page objects from it?

# %% [markdown]
# -  If a PdfFileReader object’s PDF is encrypted with the password swordfish and you're not aware of it. first read the Pdf using the PdfFileReader Class. PdfFileReader class provides a attribute called isEncrypted to check whether a pdf is encrypted or not. the method returns true if a pdf is encrypted and vice versa.
# - if pdf is encrypted use the decrypt() method provided by PdfFileReader class first then try to read the contents/pages of the pdf, else PyPDF2 will raise the following error PyPDF2.utils.PdfReadError: file has not been decrypted

# %% [markdown]
# Q5 What methods do you use to rotate a page?

# %% [markdown]
# - it having two menthods
#   1. `rotateClockWise()`
#   2. `rotateCounterClockwise()`

# %% [markdown]
# Q6 What is the difference between a Run object and a Paragraph object?

# %% [markdown]
# Paragraph Object | Run Object
# - | -
# The structure of a document is represented by three different data types in python-Docx.<br> At the highest level, a Document object represents the entire document.<br>The Document object contains a list of Paragraph objects for the paragraphs in the document.<br> Each of these Paragraph objects contains a list of one or more Run objects.| The text in a Word document is more than just a string.<br> It has font, size, color, and other styling information associated with it.<br> A style in Word is a collection of these attributes. A Run object is a contiguous run of text with the same style.<br> A new Run object is needed whenever the text style changes.

# %% [markdown]
# Q7 How do you obtain a list of Paragraph objects for a Document object that’s stored in a variable
# named doc?

# %% [markdown]
# from docx import Document<br>
# doc = Document("sample_file.docx") # Path of the Docx file<br>
# print(doc.paragraphs)

# %% [markdown]
# Q8 What type of object has bold, underline, italic, strike, and outline variables?

# %% [markdown]
# - Run object has bold, underline, italic, strike, and outline variables. The text in a Word document is more than just a string. It has font, size, color, and other styling information associated with it.
#
# - A style in Word is a collection of these attributes. A Run object is a contiguous run of text with the same style. A new Run object is needed whenever the text style changes.

# %% [markdown]
# Q9 What is the difference between False, True, and None for the bold variable?

# %% [markdown]
# bold = True  # Style Set to Bold<br>
# bold = False # Style Not Set to Bold<br>
# bold = None # Style is Not Applicable

# %% [markdown]
# Q10 How do you create a Document object for a new Word document?

# %% [markdown]
# from docx import Document<br>
# document = Document()

# %% [markdown]
# Q11 How do you add a paragraph with the text &#39;Hello, there!&#39; to a Document object stored in a
# variable named doc?

# %% [markdown]
# from docx import Document<br>
# doc = Document()<br>
# doc.add_paragraph('Hello, there!')<br>
# doc.save('hello.docx')

# %% [markdown]
# Q12 What integers represent the levels of headings available in Word documents?

# %% [markdown]
# - The levels for a heading in a word document can be specified by using the level attribute inside the add_heading method.
# - There are a total of 5 levels statring for 0 t0 4. where level 0 makes a headline with the horizontal line below the text,
# - whereas the heading level 1 is the main heading.
# - Similarly, the other headings are sub-heading with their's font-sizes in decreasing order.
