# %% [markdown]
# <h1 align='center'>Assignment No 9</h1>

# %% [markdown]
# Q1. To what does a relative path refer?

# %% [markdown]
# - A Relative path refers to a location that is relative to a current directory.
# - A Relative path is used two symbols `.`,`..` which translate into the current directory and the parent directory.
# Double dots are used for moving up in the hierarchy.
# - Example `.\new.txt`

# %% [markdown]
# Q2. What does an absolute path start with your operating system?

# %% [markdown]
# - An absolute path is a path that contains the entire path to the file or directory that you need to access.
# - This path will begin at the home directory of your computer and will end with the file or directory that you wish to access.
# - Example ```Home\Desktop\new.txt```

# %% [markdown]
# Q3. What do the functions os.getcwd() and os.chdir() do?

# %% [markdown]
# - `os.getcwd()` it used to know the current working directory of the file.
# - `os.chdir()` this method is used to change the current working directory to specified path. it takes only a single argument as new directory path.

# %%
import os 
os.chdir(r"/home/new")
pwd = os.getcwd()
print("Current Working Directory Path : "+pwd)
# Out:
# Current Working Directory Path : /home/new

# %% [markdown]
# Q4. What are the . and .. folders?

# %% [markdown]
# - `.` which translate into the current directory and the parent directory.
# - `..` Double dots are used for moving up in the hierarchy

# %% [markdown]
# Q5. In C:\bacon\eggs\spam.txt, which part is the dir name, and which part is the base name?

# %% [markdown]
# - ` C:\bacon\eggs\` is the directory name
# - `spam.txt` is the base name

# %% [markdown]
# Q6. What are the three “mode” arguments that can be passed to the open() function?

# %% [markdown]
# - Access Modes for `open()` function
#   - `mode = r`: Opens the file in ready-only mode
#   - `mode = w`: Opens file in write-only mode
#   - `mode = a`: Opens file for appending new information to it

# %% [markdown]
# Q7. What happens if an existing file is opened in write mode?

# %% [markdown]
# - if the existing file opened in write mode The pointer is placed at the beginning of the file and this will overwrite any existing file with the same name. It will create a new file if one with the same name doesn't exist

# %% [markdown]
# Q8. How do you tell the difference between read() and readlines()?

# %% [markdown]
# read() | readlines()
# - | -
# it will read the whole file at once and then print out the first characters that take up as many bytes as you specify in the parameters. | it will read and print out only the first characters that take up as many bytes as you specify in the parameters.

# %% [markdown]
# Q9. What data structure does a shelf value resemble?

# %% [markdown]
# - A shelf Value resembles a dictionary value , it has keys and values, along with keys() and values methods that work simailarly to the dictionary methods of the same names.
