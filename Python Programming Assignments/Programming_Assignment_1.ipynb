# %% [markdown]
# <h2 align='center'>Programming Assignment No 1</h2>

# %% [markdown]
# Q1.	Write a Python program to print "Hello Python"?

# %%
print("Hello Python")
# Out:
# Hello Python

# %% [markdown]
# Q2.	Write a Python program to do arithmetical operations addition and division.?

# %%
a = int(input("enter value for a "))
b = int(input("enter value for b "))

print("Addition",(a+b))
print("Division",(a/b))
# Out:
# enter value for a 10
# enter value for b 5
# Addition 15
# Division 2.0

# %% [markdown]
# Q3.	Write a Python program to find the area of a triangle?

# %%
base = int(input("enter triange base "))
height = int(input("enter triangle height "))

area_of_triangle = (base*height)/2
print("Area Of Triangle :- ",area_of_triangle)
# Out:
# enter triange base 10
# enter triangle height 20
# Area Of Triangle :-  100.0

# %% [markdown]
# Q4.	Write a Python program to swap two variables?

# %%
a = 10
b = 20
print("Before swaping a : {} and b : {}".format(a,b))
b = a + b
a = b - a
b = b - a
print("After swaping a : {} and b : {}".format(a,b))
# Out:
# Before swaping a : 10 and b : 20
# After swaping a : 20 and b : 10

# %% [markdown]
# Q5.	Write a Python program to generate a random number?

# %%
import random

number = random.randint(0,100)
print("Random Number ",number)
# Out:
# Random Number  51
