# %% [markdown]
# <h1 align='center'>Assignment No 7</h1>

# %% [markdown]
# Q1.	Write a Python Program to find sum of array?

# %%
arr = [10,20,30,40,50]
sum = 0
for i in arr:
  sum = sum + i

print(sum)
# Out:
# 150

# %% [markdown]
# Q2.	Write a Python Program to find largest element in an array?

# %%
arr = [10,20,30,40,5,60,45,90]
max = arr[0]
for i in range(1,len(arr)):
  if max<arr[i]:
    max = arr[i]
print(max)
# Out:
# 90

# %% [markdown]
# Q3.	Write a Python Program for array rotation?

# %%
arr = [10,20,30,40,50,60,33]

for i in range(len(arr)):
  print(f"rotation {i+1} ",arr[i+1:] + arr[0:i]+[arr[i]] )
# Out:
# rotation 1  [20, 30, 40, 50, 60, 33, 10]
# rotation 2  [30, 40, 50, 60, 33, 10, 20]
# rotation 3  [40, 50, 60, 33, 10, 20, 30]
# rotation 4  [50, 60, 33, 10, 20, 30, 40]
# rotation 5  [60, 33, 10, 20, 30, 40, 50]
# rotation 6  [33, 10, 20, 30, 40, 50, 60]
# rotation 7  [10, 20, 30, 40, 50, 60, 33]

# %% [markdown]
# Q4.	Write a Python Program to Split the array and add the first part to the end?

# %%
arr = [10,20,30,40,40,50,60,70]
position = len(arr)//2
result = arr[position:] + arr[:position]
print(result)
# Out:
# [40, 50, 60, 70, 10, 20, 30, 40]

# %% [markdown]
# Q5.	Write a Python Program to check if given array is Monotonic?

# %%
arr = [1,2,3,4,5,7]
x = []
y = []
x.extend(arr)
y.extend(arr)
x.sort()
y.sort(reverse=True)
if x==arr or y==arr:
  print("Array is Monotonic ")
else:
  print("Array is not Monotonic ")
# Out:
# Array is Monotonic
